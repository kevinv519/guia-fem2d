# %% [markdown]
# # Guía 2 - Método de Elementos Finitos en 2D
# 1. Para la ecuación de calor utilizada en clase
# $$ \nabla(k \nabla T) = - Q $$
# Modificar la formulación del FEM para
# $$ Q = Q(x) = 2x^4-3x^2$$

# %% [markdown]
# **Desarrollo**
# Para la integral
# $$ \iint_\Omega \mathbf{N}^\top Q(x) dy dx $$
#
# Definiendo que:
# $$ \psi_{ij} = \psi_i - \psi_j ; \psi \in \{x,y\} $$
#
# Donde:
# $$ x = x_{21} \epsilon + x_{31} \eta + x_1 $$

# %%
from sympy import *
init_printing()

eps, eta, x21, x31, x2, x3, x1 = symbols('\epsilon \eta x_21 x_31 x_2 x_3 x_1')

x = (x2-x1)*eps + (x3-x1)*eta + x1
#x = x21*eps + x31*eta + x1

nt = Matrix([1-eps-eta, eps, eta])


q = (2*x**4 - 3*x**2)

# %%
b1 = Integral(Integral(nt*q, [eta, 0, 1]), [eps, 0, 1])
b1
# Out:
# 1 1
# ⌠ ⌠
# ⎮ ⎮ ⎡⎛                                              4
# ⎮ ⎮ ⎢⎝2⋅(\epsilon⋅(-x₁ + x₂) + \eta⋅(-x₁ + x₃) + x₁)  - 3⋅(\epsilon⋅(-x₁ + x₂)
# ⎮ ⎮ ⎢
# ⎮ ⎮ ⎢                ⎛                                              4
# ⎮ ⎮ ⎢       \epsilon⋅⎝2⋅(\epsilon⋅(-x₁ + x₂) + \eta⋅(-x₁ + x₃) + x₁)  - 3⋅(\ep
# ⎮ ⎮ ⎢
# ⎮ ⎮ ⎢              ⎛                                              4
# ⎮ ⎮ ⎣         \eta⋅⎝2⋅(\epsilon⋅(-x₁ + x₂) + \eta⋅(-x₁ + x₃) + x₁)  - 3⋅(\epsi
# ⌡ ⌡
# 0 0
#
#
#
#                         2⎞                       ⎤
#  + \eta⋅(-x₁ + x₃) + x₁) ⎠⋅(-\epsilon - \eta + 1)⎥
#                                                  ⎥
#                                         2⎞       ⎥
# silon⋅(-x₁ + x₂) + \eta⋅(-x₁ + x₃) + x₁) ⎠       ⎥ d(\eta) d(\epsilon)
#                                                  ⎥
#                                       2⎞         ⎥
# lon⋅(-x₁ + x₂) + \eta⋅(-x₁ + x₃) + x₁) ⎠         ⎦

# %%
integrate(integrate(nt*q, [eta, 0, 1]), [eps, 0, 1])
# Out:
# ⎡       3          3          2   2       2             2   2          3
# ⎢   4⋅x₁ ⋅x₂   4⋅x₁ ⋅x₃   2⋅x₁ ⋅x₂    4⋅x₁ ⋅x₂⋅x₃   2⋅x₁ ⋅x₃    2⋅x₁⋅x₂    16⋅
# ⎢   ──────── + ──────── - ───────── - ─────────── - ───────── + ──────── + ───
# ⎢      15         15          5            5            5          5
# ⎢
# ⎢  4       3          3          2   2        2             2   2          3
# ⎢x₁    4⋅x₁ ⋅x₂   4⋅x₁ ⋅x₃   3⋅x₁ ⋅x₂    16⋅x₁ ⋅x₂⋅x₃   8⋅x₁ ⋅x₃    8⋅x₁⋅x₂
# ⎢─── - ──────── - ──────── + ───────── + ──────────── + ───────── - ──────── -
# ⎢ 15      15         15          5            15            15         15
# ⎢
# ⎢  4       3          3          2   2        2             2   2          3
# ⎢x₁    4⋅x₁ ⋅x₂   4⋅x₁ ⋅x₃   8⋅x₁ ⋅x₂    16⋅x₁ ⋅x₂⋅x₃   3⋅x₁ ⋅x₃    7⋅x₁⋅x₂
# ⎢─── - ──────── - ──────── + ───────── + ──────────── + ───────── - ──────── -
# ⎣ 15      15         15          15           15            5          15
#
#      2                 2          3       4       3          2   2          3
# x₁⋅x₂ ⋅x₃   16⋅x₁⋅x₂⋅x₃    2⋅x₁⋅x₃    2⋅x₂    7⋅x₂ ⋅x₃   2⋅x₂ ⋅x₃    7⋅x₂⋅x₃
# ───────── + ──────────── + ──────── - ───── - ──────── - ───────── - ────────
#   15             15           5         15       15          3          15
#
#         2                2          3     4       3                       3
#  7⋅x₁⋅x₂ ⋅x₃   4⋅x₁⋅x₂⋅x₃    7⋅x₁⋅x₃    x₂    4⋅x₂ ⋅x₃     2   2   2⋅x₂⋅x₃
#  ─────────── - ─────────── - ──────── + ─── + ──────── + x₂ ⋅x₃  + ──────── +
#       5             3           15       3       5                    3
#
#         2                2          3     4       3                       3
#  4⋅x₁⋅x₂ ⋅x₃   7⋅x₁⋅x₂⋅x₃    8⋅x₁⋅x₃    x₂    2⋅x₂ ⋅x₃     2   2   4⋅x₂⋅x₃
#  ─────────── - ─────────── - ──────── + ─── + ──────── + x₂ ⋅x₃  + ──────── +
#       3             5           15       5       3                    5
#
#       4                     2             2    ⎤
#   2⋅x₃    x₁⋅x₂   x₁⋅x₃   x₂    x₂⋅x₃   x₃     ⎥
# - ───── - ───── - ───── + ─── + ───── + ───    ⎥
#     15      2       2      4      2      4     ⎥
#                                                ⎥
#   4     2                       2             2⎥
# x₃    x₁    x₁⋅x₂   x₁⋅x₃   3⋅x₂            x₃ ⎥
# ─── - ─── + ───── + ───── - ───── - x₂⋅x₃ - ───⎥
#  5     4      2       2       4              2 ⎥
#                                                ⎥
#   4     2                     2               2⎥
# x₃    x₁    x₁⋅x₂   x₁⋅x₃   x₂            3⋅x₃ ⎥
# ─── - ─── + ───── + ───── - ─── - x₂⋅x₃ - ─────⎥
#  3     4      2       2      2              4  ⎦

# %% [markdown]
# La primera observación que se puede hacer es que ahora, nuestra x está definida en función de las variables isoparamétricas $\{\epsilon, \eta\}$ y por consiguiente, al multiplicarle por el vector columna que representa las funciones de forma transpuesta, nos damos cuenta que el resultado ya no serían los mismo valores, como en la formulación original del método para 2D con $Q$ constante
